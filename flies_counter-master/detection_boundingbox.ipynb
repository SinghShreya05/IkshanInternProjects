# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import matplotlib.pyplot as plt

from utils import *
from darknet import Darknet

# %%
import darknet

# %%
# Set the location and name of the cfg file
cfg_file = "/content/drive/MyDrive/Colab Notebooks/cfg/yolov3.cfg"

# Set the location and name of the pre-trained weights file
weight_file = "/content/drive/MyDrive/Colab Notebooks/yolov3.weights"

# Set the location and name of the COCO object classes file
namesfile = "/content/drive/MyDrive/Colab Notebooks/data/coco.names"

# Load the network architecture
m = Darknet(cfg_file)

# Load the pre-trained weights
m.load_weights(weight_file)

# Load the COCO object classes
class_names = load_class_names(namesfile)

# %%
# Print the neural network used in YOLOv3
m.print_network()
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32
#     1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64
#     2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32
#     3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64
#     4 shortcut 1
#     5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128
#     6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64
#     7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128
#     8 shortcut 5
#     9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64
#    10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128
#    11 shortcut 8
#    12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256
#    13 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
#    14 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
# ...

# %%
# Set the default figure size
plt.rcParams['figure.figsize'] = [24.0, 14.0]

# Load the image
img = cv2.imread('/content/drive/MyDrive/anim.jpg')

# Convert the image to RGB
original_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# We resize the image to the input width and height of the first layer of the network.    
resized_image = cv2.resize(original_image, (m.width, m.height))

# Display the images
plt.subplot(121)
plt.title('Original Image')
plt.imshow(original_image)
plt.subplot(122)
plt.title('Resized Image')
plt.imshow(resized_image)
plt.show()

# %%
# Set the NMS threshold
nms_thresh = 0.6

# %%
# Set the IOU threshold
iou_thresh = 0.4

# %%
# Set the default figure size
plt.rcParams['figure.figsize'] = [24.0, 14.0]

# Load the image
img = cv2.imread('/content/drive/MyDrive/anim.jpg')

# Convert the image to RGB
original_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# We resize the image to the input width and height of the first layer of the network.    
resized_image = cv2.resize(original_image, (m.width, m.height))

# Set the IOU threshold. Default value is 0.4
iou_thresh = 0.4

# Set the NMS threshold. Default value is 0.6
nms_thresh = 0.6

# Detect objects in the image
boxes = detect_objects(m, resized_image, iou_thresh, nms_thresh)

# Print the objects found and the confidence level
print_objects(boxes, class_names)

#Plot the image with bounding boxes and corresponding object class labels
plot_boxes(original_image, boxes, class_names, plot_labels = True)
# Out:
# It took 1.160 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2
#
# Objects Found and Confidence Level:
#
# 1. dog: 1.000000
# 2. dog: 1.000000

# %%
boxes = detect_objects(m, resized_image, iou_thresh, nms_thresh)
# Out:
# It took 1.319 seconds to detect the objects in the image.
#
# Number of Objects Detected: 2

# %%
num = print_objects(boxes, class_names)
# Out:
# Objects Found and Confidence Level:
#
# 1. dog: 1.000000
# 2. dog: 1.000000

# %%
type(num)
# Out:
# NoneType

# %%
plt.rcParams['figure.figsize'] = [24.0, 14.0]

# Load the image
img = cv2.imread('/content/drive/MyDrive/flies.jpg')

# Convert the image to RGB
original_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# We resize the image to the input width and height of the first layer of the network.    
resized_image = cv2.resize(original_image, (m.width, m.height))

# Set the IOU threshold. Default value is 0.4
iou_thresh = 0.4

# Set the NMS threshold. Default value is 0.6
nms_thresh = 0.6

# Detect objects in the image
boxes = detect_objects(m, resized_image, iou_thresh, nms_thresh)

# Print the objects found and the confidence level
print_objects(boxes, class_names)
# Out:
# It took 1.131 seconds to detect the objects in the image.
#
# Number of Objects Detected: 0
#
# Objects Found and Confidence Level:
